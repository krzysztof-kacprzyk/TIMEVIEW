# %%
import sys
sys.path.append('../')

from benchmarks.benchmark import run_all_benchmarks, GAM, XTYDataset, TTSBenchmark
from tts.data import synthetic_tumor_data
from tts.config import Config

seed = 0

X, ts, ys = synthetic_tumor_data(1000,20,1.0,0.0,seed=seed,equation='wilkerson')
dataset = XTYDataset(X, ts, ys)

gam = GAM()

config = Config(n_features=4, n_basis=5, T=1, seed=seed, dataloader_type='iterative')
tts = TTSBenchmark(config)

run_all_benchmarks(dataset, [gam], seed=seed, n_trials=1,n_tune=1)
# Out:
# [I 2023-04-18 12:21:31,357] A new study created in memory with name: no-name-cffd5a45-d4e6-4cf8-bedc-ad5850d6e547
# ...
