# %%
# This script is used to create Table 3 in the paper
# It requires running Table_3.sh to generate the results

import sys
sys.path.append('../../')
import pandas as pd
import matplotlib.pyplot as plt
from experiments.analysis.analysis_utils import find_results, load_result_from_timestamp
from experiments.benchmark import create_benchmark_datasets_if_not_exist
from tabulate import tabulate

# Change this to true only if you have access to the tacrolimus dataset
access_to_tacrolimus = False

create_benchmark_datasets_if_not_exist(dataset_description_path="../dataset_descriptions")

def create_df_row(dataset_name, model_name, n_basis):
    if n_basis is not None:
        results = find_results(dataset_name, model_name, filter_dict={"notes": f"n_basis={n_basis},rnn_type=lstm"})
    else:
        results = find_results(dataset_name, model_name)
    if len(results) == 0:
        print(f"No results found for {dataset_name} and {model_name} with n_basis={n_basis}")
        print("Make sure you run your experiments from ../run_scripts")
        # Return an empty row
        return pd.DataFrame(columns=["dataset", "method", "error_mean", "error_std"])
    elif len(results) > 1:
        print("Multiple results found for the given dataset and model")
        print("We take the last one but it may produce unexpected results")
    result = load_result_from_timestamp(results[-1])
    row = pd.DataFrame({"dataset": dataset_name,
                        "method": model_name,
                        "error_mean": result["results"][model_name]["mean"], 
                        "error_std": result["results"][model_name]["std"]}, index=[0])
    return row

# Get all timestamps

datasets =  [
            'synthetic_tumor_wilkerson_1',
            'airfoil_log',
            'flchain_1000',
            'stress-strain-lot-max-0.2',
            'sine_trans_200_20',
            'beta_900_20']

if access_to_tacrolimus:
    datasets.append("tacrolimus_visit_12")

baselines = [
    'TTS',
    'XGB',
    'RNN',
    'GAM',
    'SINDy',
    'DeltaTRNN',
    'CatBoost',
    'LGBM',
    'DecisionTree',
    'Linear',
    'PySR'
]

df = pd.DataFrame(columns=["dataset", "method", "error_mean", "error_std"])

for dataset in datasets:
    for baseline in baselines:
        if baseline == 'RNN' and dataset in ['airfoil_log','stress-strain-lot-max-0.2','tacrolimus_visit_12']:
           continue # RNN is not run on these datasets as it requires regular time intervals
        if dataset in ['sine_trans_200_20', 'beta_900_20']:
            n_basis = 5
        else:
            n_basis = 9
        if baseline == 'PySR':
            n_basis = None
        df = pd.concat([df, create_df_row(dataset, baseline, n_basis)], ignore_index=True)

# Reorder the columns
df = df[['method','dataset','error_mean','error_std']]

# Change dataset names
new_dataset_names = {
    "airfoil_log":"Airfoil",
    "celgene":"Celgene",
    "flchain_1000":"flchain",
    "stress-strain-lot-max-0.2":"Stress-Strain",
    "synthetic_tumor_wilkerson_1":"Tumor",
    "tacrolimus_visit_12":"Tacrolimus",
    "sine_trans_200_20": "Sine",
    "beta_900_20": "Beta",
}

df['dataset'] = df['dataset'].map(new_dataset_names)

# Change method names
new_method_names = {
    "TTS":"TIMEVIEW",
    "XGB":"XGB-T",
    "RNN":"RNN",
    "GAM":"GAM-T",
    "SINDy":"SINDy",
    "DeltaTRNN":"Dt-RNN",
    "CatBoost":"CatBoost-T",
    "LGBM":"LGBM-T",
    "DecisionTree":"DecisionTree-T",
    "Linear":"Linear-T",
    "PySR":"PySR"
}

df['method'] = df['method'].map(new_method_names)

# Pivot the dataframe to have datasets as columns and methods as rows
pivot_df = df.pivot_table(index='method', columns='dataset', values=['error_mean', 'error_std'])

# Switch the column levels and sort them
pivot_df = pivot_df.swaplevel(axis=1).sort_index(axis=1)

methods_in_order = ['RNN',"Dt-RNN","XGB-T",'LGBM-T','CatBoost-T','PySR','SINDy','Linear-T','DecisionTree-T','GAM-T','TIMEVIEW']

if access_to_tacrolimus:
    datasets_in_order = ["Airfoil", "flchain","Stress-Strain", "Tacrolimus", "Tumor", "Sine", "Beta"]
else:
    datasets_in_order = ["Airfoil", "flchain","Stress-Strain", "Tumor", "Sine", "Beta"]

pivot_df = pivot_df.loc[methods_in_order,:]

# Format the table cells to show mean and std as mean ± std
def format_mean_std(row):
    formatted_row = {}
    for dataset in datasets_in_order:
        mean, std = row[(dataset,'error_mean')], row[(dataset,'error_std')]
        formatted_row[dataset] = f"{mean:.2f} ± {std:.2f}"
    return pd.Series(formatted_row)

formatted_df = pivot_df.apply(format_mean_std, axis=1)

# Generate the LaTeX table
latex_table = tabulate(formatted_df, tablefmt='latex_booktabs', headers='keys', showindex=True, floatfmt=".2f")

# Print the LaTeX table
print(latex_table)

# Save the LaTeX table to a file
# with open("tables/Table_3.tex", "w") as f:
#     f.write(latex_table)
# Out:
# No results found for synthetic_tumor_wilkerson_1 and TTS with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for synthetic_tumor_wilkerson_1 and XGB with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for synthetic_tumor_wilkerson_1 and RNN with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for synthetic_tumor_wilkerson_1 and GAM with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for synthetic_tumor_wilkerson_1 and SINDy with n_basis=9
# Make sure you run your experiments from ../run_scripts
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# No results found for tumor and TTS with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for tumor and XGB with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for tumor and RNN with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for tumor and GAM with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for tumor and SINDy with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for tumor and DeltaTRNN with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for tumor and CatBoost with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for tumor and LGBM with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for tumor and DecisionTree with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for tumor and Linear with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for tumor and PySR with n_basis=None
# Make sure you run your experiments from ../run_scripts
# No results found for airfoil_log and XGB with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for airfoil_log and GAM with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for airfoil_log and SINDy with n_basis=9
# Make sure you run your experiments from ../run_scripts
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# No results found for celgene and TTS with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for celgene and XGB with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for celgene and RNN with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for celgene and GAM with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for celgene and SINDy with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for celgene and DeltaTRNN with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for celgene and CatBoost with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for celgene and LGBM with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for celgene and DecisionTree with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for celgene and Linear with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for celgene and PySR with n_basis=None
# Make sure you run your experiments from ../run_scripts
# No results found for flchain_1000 and TTS with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for flchain_1000 and XGB with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for flchain_1000 and RNN with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for flchain_1000 and GAM with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for flchain_1000 and SINDy with n_basis=9
# Make sure you run your experiments from ../run_scripts
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# No results found for stress-strain-lot-max-0.2 and TTS with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for stress-strain-lot-max-0.2 and XGB with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for stress-strain-lot-max-0.2 and GAM with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for stress-strain-lot-max-0.2 and SINDy with n_basis=9
# Make sure you run your experiments from ../run_scripts
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# No results found for tacrolimus_visit_12 and XGB with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for tacrolimus_visit_12 and GAM with n_basis=9
# Make sure you run your experiments from ../run_scripts
# No results found for tacrolimus_visit_12 and SINDy with n_basis=9
# Make sure you run your experiments from ../run_scripts
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# No results found for sine_trans_200_20 and TTS with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for sine_trans_200_20 and XGB with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for sine_trans_200_20 and RNN with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for sine_trans_200_20 and GAM with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for sine_trans_200_20 and SINDy with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for sine_trans_200_20 and DeltaTRNN with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for sine_trans_200_20 and CatBoost with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for sine_trans_200_20 and LGBM with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for sine_trans_200_20 and DecisionTree with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for sine_trans_200_20 and Linear with n_basis=5
# Make sure you run your experiments from ../run_scripts
# Multiple results found for the given dataset and model
# We take the last one but it may produce unexpected results
# No results found for beta_900_20 and TTS with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for beta_900_20 and XGB with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for beta_900_20 and RNN with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for beta_900_20 and GAM with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for beta_900_20 and SINDy with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for beta_900_20 and DeltaTRNN with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for beta_900_20 and CatBoost with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for beta_900_20 and LGBM with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for beta_900_20 and DecisionTree with n_basis=5
# Make sure you run your experiments from ../run_scripts
# No results found for beta_900_20 and Linear with n_basis=5
# Make sure you run your experiments from ../run_scripts
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 118
#     114 methods_in_order = ['RNN',"Dt-RNN","XGB-T",'LGBM-T','CatBoost-T','PySR','SINDy','Linear-T','DecisionTree-T','GAM-T','TIMEVIEW']
#     115 datasets_in_order = ["Airfoil", "flchain","Stress-Strain", "Tacrolimus", "Tumor", "Sine", "Beta"]
# --> 118 pivot_df = pivot_df.loc[methods_in_order,:]
#     120 # Format the table cells to show mean and std as mean ± std
#     121 def format_mean_std(row):
#
# File c:\Users\krkac\Miniconda3\envs\tts\lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File c:\Users\krkac\Miniconda3\envs\tts\lib\site-packages\pandas\core\indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
#    1283 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\krkac\Miniconda3\envs\tts\lib\site-packages\pandas\core\indexing.py:976, in _LocationIndexer._getitem_lowerdim(self, tup)
#     974 # we may have a nested tuples indexer here
#     975 if self._is_nested_tuple_indexer(tup):
# --> 976     return self._getitem_nested_tuple(tup)
#     978 # we maybe be using a tuple to represent multiple dimensions here
#     979 ax0 = self.obj._get_axis(0)
#
# File c:\Users\krkac\Miniconda3\envs\tts\lib\site-packages\pandas\core\indexing.py:1077, in _LocationIndexer._getitem_nested_tuple(self, tup)
#    1074     axis -= 1
#    1075     continue
# -> 1077 obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1078 axis -= 1
#    1080 # if we have a scalar, we are done
#
# File c:\Users\krkac\Miniconda3\envs\tts\lib\site-packages\pandas\core\indexing.py:1332, in _LocIndexer._getitem_axis(self, key, axis)
#    1329     if hasattr(key, "ndim") and key.ndim > 1:
#    1330         raise ValueError("Cannot index with multidimensional key")
# -> 1332     return self._getitem_iterable(key, axis=axis)
#    1334 # nested tuple slicing
#    1335 if is_nested_tuple(key, labels):
#
# File c:\Users\krkac\Miniconda3\envs\tts\lib\site-packages\pandas\core\indexing.py:1272, in _LocIndexer._getitem_iterable(self, key, axis)
#    1269 self._validate_key(key, axis)
#    1271 # A collection of keys
# -> 1272 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1273 return self.obj._reindex_with_indexers(
#    1274     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1275 )
#
# File c:\Users\krkac\Miniconda3\envs\tts\lib\site-packages\pandas\core\indexing.py:1462, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1459 ax = self.obj._get_axis(axis)
#    1460 axis_name = self.obj._get_axis_name(axis)
# -> 1462 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1464 return keyarr, indexer
#
# File c:\Users\krkac\Miniconda3\envs\tts\lib\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File c:\Users\krkac\Miniconda3\envs\tts\lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['RNN', 'XGB-T', 'SINDy', 'GAM-T'] not in index"
